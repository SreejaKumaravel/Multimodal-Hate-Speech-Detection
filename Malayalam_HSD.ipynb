# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %% [markdown]
# #Text

# %% [markdown]
# **SVM**

# %%
from sklearn.utils.class_weight import compute_class_weight
import numpy as np
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.svm import SVC

# Load the Malayalam dataset
train_data = pd.read_csv("/content/drive/MyDrive/Project/Malayam/ML-AT-train.csv")
test_data = pd.read_csv("/content/drive/MyDrive/Project/Test/Malayalam/ML-AT-test.csv")

# Step 1: Preprocess Malayalam text
def preprocess_text(text):
    # Add more preprocessing steps as needed for Malayalam
    text = text.lower()  # Convert to lowercase
    text = ''.join(char for char in text if char.isalnum() or char.isspace())  # Remove punctuation
    return text

train_data['Transcript'] = train_data['Transcript'].apply(preprocess_text)
test_data['Transcript'] = test_data['Transcript'].apply(preprocess_text)

# Step 2: Check class distribution in training data
class_counts = train_data['Class Label Short'].value_counts()
print("Class distribution:", class_counts)

# Step 3: Compute class weights for imbalanced dataset
class_weights = compute_class_weight('balanced', classes=np.unique(train_data['Class Label Short']), y=train_data['Class Label Short'])
class_weight_dict = dict(zip(np.unique(train_data['Class Label Short']), class_weights))
print("Class weights:", class_weight_dict)

# Step 4: Prepare the text data (transcripts) and labels
X_train = train_data['Transcript']
y_train = train_data['Class Label Short']
X_test = test_data['Transcript']

# Convert labels to numeric format
label_encoder = LabelEncoder()
y_train_numeric = label_encoder.fit_transform(y_train)

# Step 5: Extract CountVectorizer features from text
vectorizer = CountVectorizer(max_features=5000, ngram_range=(1, 2), analyzer='char', max_df=0.9, min_df=5)
X_train_cv = vectorizer.fit_transform(X_train)
X_test_cv = vectorizer.transform(X_test)

# Step 6: Train an SVM model
svm_model = SVC(kernel='rbf', class_weight='balanced', probability=True, random_state=42)
svm_model.fit(X_train_cv, y_train_numeric)

# Step 7: Predict class labels for test data
y_test_pred = svm_model.predict(X_test_cv)

# Convert numeric predictions back to string labels
y_test_pred_labels = label_encoder.inverse_transform(y_test_pred)

# Step 8: Save predictions in a TSV file with 'filename' and 'Predicted_Label' columns
test_data['Predicted_Label'] = y_test_pred_labels

# Assuming 'File Name' is a column in test_data (adjust if needed)
predictions = test_data[['File Name', 'Predicted_Label']]

# Save to TSV file
predictions.to_csv("CV_SVM_prediction.tsv", sep='\t', index=False)
print("Predictions saved to CV_SVM_prediction.tsv")
# Out:
# Class distribution: Class Label Short
# N    406
# C    186
# P    118
# R     91
# G     82
# Name: count, dtype: int64
# Class weights: {'C': 0.9494623655913978, 'G': 2.153658536585366, 'N': 0.4349753694581281, 'P': 1.4966101694915255, 'R': 1.9406593406593406}
# Predictions saved to CV_SVM_prediction.tsv

# %% [markdown]
# **Logistic Regression**

# %%
from sklearn.utils.class_weight import compute_class_weight
import numpy as np
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.linear_model import LogisticRegression

# Load the Malayalam dataset
train_data = pd.read_csv("/content/drive/MyDrive/Project/Malayam/ML-AT-train.csv")
test_data = pd.read_csv("/content/drive/MyDrive/Project/Test/Malayalam/ML-AT-test.csv")

# Step 1: Preprocess Malayalam text
def preprocess_text(text):
    # Add more preprocessing steps as needed for Malayalam
    text = text.lower()  # Convert to lowercase
    text = ''.join(char for char in text if char.isalnum() or char.isspace())  # Remove punctuation
    return text

train_data['Transcript'] = train_data['Transcript'].apply(preprocess_text)
test_data['Transcript'] = test_data['Transcript'].apply(preprocess_text)

# Step 2: Check class distribution in training data
class_counts = train_data['Class Label Short'].value_counts()
print("Class distribution:", class_counts)

# Step 3: Compute class weights for imbalanced dataset
class_weights = compute_class_weight('balanced', classes=np.unique(train_data['Class Label Short']), y=train_data['Class Label Short'])
class_weight_dict = dict(zip(np.unique(train_data['Class Label Short']), class_weights))
print("Class weights:", class_weight_dict)

# Step 4: Prepare the text data (transcripts) and labels
X_train = train_data['Transcript']
y_train = train_data['Class Label Short']
X_test = test_data['Transcript']

# Convert labels to numeric format
label_encoder = LabelEncoder()
y_train_numeric = label_encoder.fit_transform(y_train)

# Step 5: Extract TF-IDF features from text
vectorizer = TfidfVectorizer(max_features=5000, ngram_range=(1, 2), analyzer='char', max_df=0.9, min_df=5)
X_train_tfidf = vectorizer.fit_transform(X_train)
X_test_tfidf = vectorizer.transform(X_test)

# Step 6: Train an SVM model
model = LogisticRegression(class_weight='balanced', solver='liblinear', random_state=42)
model.fit(X_train_tfidf, y_train_numeric)

# Step 7: Predict class labels for test data
y_test_pred = svm_model.predict(X_test_tfidf)

# Convert numeric predictions back to string labels
y_test_pred_labels = label_encoder.inverse_transform(y_test_pred)

# Step 8: Save predictions in a TSV file with 'filename' and 'Predicted_Label' columns
test_data['Predicted_Label'] = y_test_pred_labels

# Assuming 'File Name' is a column in test_data (adjust if needed)
predictions = test_data[['File Name', 'Predicted_Label']]

# Save to TSV file
predictions.to_csv("Logistic_prediction.tsv", sep='\t', index=False)
print("Predictions saved to Logistic_prediction.tsv")
# Out:
# Class distribution: Class Label Short
# N    406
# C    186
# P    118
# R     91
# G     82
# Name: count, dtype: int64
# Class weights: {'C': 0.9494623655913978, 'G': 2.153658536585366, 'N': 0.4349753694581281, 'P': 1.4966101694915255, 'R': 1.9406593406593406}
# Predictions saved to Logistic_prediction.tsv

# %% [markdown]
# **MLP classifier**

# %%
from sklearn.utils.class_weight import compute_class_weight
import numpy as np
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.neural_network import MLPClassifier

# Load the Malayalam dataset
train_data = pd.read_csv("/content/drive/MyDrive/Project/Malayam/ML-AT-train.csv")
test_data = pd.read_csv("/content/drive/MyDrive/Project/Test/Malayalam/ML-AT-test.csv")

# Step 1: Preprocess Malayalam text
def preprocess_text(text):
    # Add more preprocessing steps as needed for Malayalam
    text = text.lower()  # Convert to lowercase
    text = ''.join(char for char in text if char.isalnum() or char.isspace())  # Remove punctuation
    return text

train_data['Transcript'] = train_data['Transcript'].apply(preprocess_text)
test_data['Transcript'] = test_data['Transcript'].apply(preprocess_text)

# Step 2: Check class distribution in training data
class_counts = train_data['Class Label Short'].value_counts()
print("Class distribution:", class_counts)

# Step 3: Compute class weights for imbalanced dataset
class_weights = compute_class_weight('balanced', classes=np.unique(train_data['Class Label Short']), y=train_data['Class Label Short'])
class_weight_dict = dict(zip(np.unique(train_data['Class Label Short']), class_weights))
print("Class weights:", class_weight_dict)

# Step 4: Prepare the text data (transcripts) and labels
X_train = train_data['Transcript']
y_train = train_data['Class Label Short']
X_test = test_data['Transcript']

# Convert labels to numeric format
label_encoder = LabelEncoder()
y_train_numeric = label_encoder.fit_transform(y_train)

# Step 5: Extract TF-IDF features from text
vectorizer = TfidfVectorizer(max_features=5000, ngram_range=(1, 2), analyzer='char', max_df=0.9, min_df=5)
X_train_tfidf = vectorizer.fit_transform(X_train)
X_test_tfidf = vectorizer.transform(X_test)

# Step 6: Train an MLPClassifier
mlp_model = MLPClassifier(hidden_layer_sizes=(128, 64), activation='relu', solver='adam', max_iter=50, random_state=42)
mlp_model.fit(X_train_tfidf, y_train_numeric)

# Step 7: Predict class labels for test data
y_test_pred = mlp_model.predict(X_test_tfidf)

# Convert numeric predictions back to string labels
y_test_pred_labels = label_encoder.inverse_transform(y_test_pred)

# Step 8: Save predictions in a TSV file with 'filename' and 'Predicted_Label' columns
test_data['Predicted_Label'] = y_test_pred_labels

# Assuming 'File Name' is a column in test_data (adjust if needed)
predictions = test_data[['File Name', 'Predicted_Label']]

# Save to TSV file
predictions.to_csv("MLP_prediction.tsv", sep='\t', index=False)
print("Predictions saved to MLP_prediction.tsv")
# Out:
# Class distribution: Class Label Short
# N    406
# C    186
# P    118
# R     91
# G     82
# Name: count, dtype: int64
# Class weights: {'C': 0.9494623655913978, 'G': 2.153658536585366, 'N': 0.4349753694581281, 'P': 1.4966101694915255, 'R': 1.9406593406593406}
# Predictions saved to MLP_prediction.tsv
# /usr/local/lib/python3.11/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (50) reached and the optimization hasn't converged yet.
#   warnings.warn(

# %%
import pandas as pd

# Load the TSV file
file_path = "/content/ML-AT-test.xlsx - Sheet1.tsv"
df = pd.read_csv(file_path, sep="\t")

# Change column name (e.g., from 'Old_Column_Name' to 'New_Column_Name')
df.rename(columns={"File Name": "File_Name"}, inplace=True)

# Save the updated DataFrame back to the TSV file
output_path = "/content/ML-AT-test.xlsx - Sheet1.tsv"
df.to_csv(output_path, sep="\t", index=False)

print(f"Updated file saved to {output_path}")
# Out:
# Updated file saved to /content/ML-AT-test.xlsx - Sheet1.tsv

# %% [markdown]
# **Fusion with weight**

# %%
import pandas as pd
from collections import Counter

# File paths (update if necessary)
logistic_predictions_path = "/content/Logistic_prediction.tsv"
mlp_predictions_path = "/content/MLP_prediction.tsv"
svm_predictions_path = "/content/CV_SVM_prediction.tsv"  # New file
output_fused_predictions_path ="/content/Text_fusion_weight.tsv"


# Load predictions
logistic_predictions = pd.read_csv(logistic_predictions_path, sep="\t")
mlp_predictions = pd.read_csv(mlp_predictions_path, sep="\t")
svm_predictions = pd.read_csv(svm_predictions_path, sep="\t")  # Load additional predictions

# Ensure all files have the same filenames in the same order
if not (
    all(logistic_predictions['File_Name'] == mlp_predictions['File_Name']) and
    all(logistic_predictions['File_Name'] == svm_predictions['File_Name'])
):
    raise ValueError("Mismatch in filenames between the prediction files.")

# Majority fusion with different weights
fused_predictions = []
for _, (log_row, mlp_row, svm_row) in enumerate(zip(
    logistic_predictions.itertuples(),
    mlp_predictions.itertuples(),
    svm_predictions.itertuples()
)):
    File_Name = log_row.File_Name
    log_label = log_row.Predicted_Label
    mlp_label = mlp_row.Predicted_Label
    svm_label = svm_row.Predicted_Label

    # Weighted voting
    vote_counter = Counter()
    vote_counter[log_label] += 2 # Weight 1 for Logistic regression
    vote_counter[mlp_label] +=  3 # Weight 2 for MLP
    vote_counter[svm_label] += 1  # Weight 1 for additional model

    # Majority vote
    fused_label = vote_counter.most_common(1)[0][0]
    fused_predictions.append({"File_Name": File_Name, "fused_label": fused_label})

# Save fused predictions to a new TSV file
fused_predictions_df = pd.DataFrame(fused_predictions)
fused_predictions_df.to_csv(output_fused_predictions_path, sep="\t", index=False)
print(f"Fused predictions saved to {output_fused_predictions_path}.")
# Out:
# Fused predictions saved to /content/Text_fusion_weight.tsv.

# %% [markdown]
# **Fusion without weight**

# %%
import pandas as pd
from collections import Counter

# File paths (update if necessary)
logistic_predictions_path = "/content/Logistic_prediction.tsv"
mlp_predictions_path = "/content/MLP_prediction.tsv"
svm_predictions_path = "/content/CV_SVM_prediction.tsv"  # New file
output_fused_predictions_path = "/content/Text_fusion.tsv"

# Load predictions
logistic_predictions = pd.read_csv(logistic_predictions_path, sep="\t")
mlp_predictions = pd.read_csv(mlp_predictions_path, sep="\t")
svm_predictions = pd.read_csv(svm_predictions_path, sep="\t")  # Load additional predictions

# Ensure all files have the same filenames in the same order
if not (
    all(logistic_predictions['File_Name'] == mlp_predictions['File_Name']) and
    all(logistic_predictions['File_Name'] == svm_predictions['File_Name'])
):
    raise ValueError("Mismatch in filenames between the prediction files.")

# Majority fusion without weighting
fused_predictions = []
for _, (log_row, mlp_row, svm_row) in enumerate(zip(
    logistic_predictions.itertuples(),
    mlp_predictions.itertuples(),
    svm_predictions.itertuples()
)):
    File_Name = log_row.File_Name
    log_label = log_row.Predicted_Label
    mlp_label = mlp_row.Predicted_Label
    svm_label = svm_row.Predicted_Label

    # Equal voting
    vote_counter = Counter([log_label, mlp_label, svm_label])

    # Majority vote
    fused_label = vote_counter.most_common(1)[0][0]
    fused_predictions.append({"File_Name": File_Name, "fused_label": fused_label})

# Save fused predictions to a new TSV file
fused_predictions_df = pd.DataFrame(fused_predictions)
fused_predictions_df.to_csv(output_fused_predictions_path, sep="\t", index=False)
print(f"Fused predictions saved to {output_fused_predictions_path}.")
# Out:
# Fused predictions saved to /content/Text_fusion.tsv.

# %% [markdown]
# #Audio

# %% [markdown]
# **Random Forest**

# %%
import pandas as pd
import librosa
import numpy as np
import os
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import LabelEncoder
from sklearn.utils.class_weight import compute_class_weight

# Paths (update with actual paths)
train_csv_path = "/content/drive/MyDrive/Project/Malayam/ML-AT-train.csv"
train_audio_dir = "/content/drive/MyDrive/Project/Malayam/audio"
test_audio_dir = "//content/drive/MyDrive/Project/Test/Malayalam/audio"
output_tsv_path = "Random_audio_predictions.tsv"

# Step 1: Load train.csv to map class labels
train_df = pd.read_csv(train_csv_path)
train_df['Class Label Short'] = train_df['Class Label Short'].astype(str)

# Step 2: Preprocessing Malayalam audio (MFCC feature extraction)
def preprocess_audio(file_path, sr=16000):
    try:
        y, original_sr = librosa.load(file_path, sr=None)
        # Resample if necessary
        if original_sr != sr:
            y = librosa.resample(y, orig_sr=original_sr, target_sr=sr)
        # Trim silence from audio
        y, _ = librosa.effects.trim(y)
        # Extract MFCC (Mel Frequency Cepstral Coefficients)
        mfccs = librosa.feature.mfcc(y=y, sr=sr, n_mfcc=13)
        print(f"MFCC shape for {file_path}: {mfccs.shape}")  # Debugging line
        return np.mean(mfccs, axis=1)
    except Exception as e:
        print(f"Error processing file {file_path}: {e}")
        return None

X_train, y_train = [], []
for _, row in train_df.iterrows():
    file_path = os.path.join(train_audio_dir, row['File Name'] + ".wav")  # Add .wav extension
    if os.path.exists(file_path):
        features = preprocess_audio(file_path)
        if features is not None:
            X_train.append(features)
            y_train.append(row['Class Label Short'])
        else:
            print(f"Skipping file {file_path} due to feature extraction failure.")
    else:
        print(f"File not found: {file_path}")

X_train = np.array(X_train)

# Check if X_train is empty
if X_train.size == 0:
    print("No valid training data found. Please check file paths and data.")
else:
    # Proceed with model training
    label_encoder = LabelEncoder()
    y_train_encoded = label_encoder.fit_transform(y_train)

    # Step 3: Compute class weights
    class_weights = compute_class_weight(
        class_weight="balanced",
        classes=np.unique(y_train_encoded),
        y=y_train_encoded
    )
    class_weight_dict = {i: weight for i, weight in enumerate(class_weights)}
    print(f"Class weights: {class_weight_dict}")

    # Train Random Forest Classifier with class weights
    clf = RandomForestClassifier(class_weight=class_weight_dict)
    clf.fit(X_train, y_train_encoded)
    print("Model trained successfully.")

# Step 4: Predict for test data
test_predictions = []
test_files = [f for f in os.listdir(test_audio_dir) if f.endswith('.wav')]  # Adjust if needed
for file_name in test_files:
    file_path = os.path.join(test_audio_dir, file_name)
    features = preprocess_audio(file_path)
    if features is not None:
        predicted_label_encoded = clf.predict([features])
        predicted_label = label_encoder.inverse_transform(predicted_label_encoded)[0]
        test_predictions.append({"File_Name": file_name, "predicted_label": predicted_label})
    else:
        print(f"Skipping file {file_path} due to feature extraction failure.")

# Step 5: Save predictions to a TSV file
test_predictions_df = pd.DataFrame(test_predictions)
test_predictions_df.to_csv(output_tsv_path, sep="\t", index=False)
print(f"Predictions saved to {output_tsv_path}.")
# Out:
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_C_F_044_001.wav: (13, 141)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_C_F_044_002.wav: (13, 252)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_C_F_044_003.wav: (13, 127)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_C_F_044_004.wav: (13, 189)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_C_F_044_005.wav: (13, 127)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_C_F_044_006.wav: (13, 252)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_C_F_044_007.wav: (13, 95)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_C_F_044_008.wav: (13, 127)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_C_F_044_009.wav: (13, 127)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_C_F_044_010.wav: (13, 252)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_C_F_044_011.wav: (13, 283)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_C_F_044_012.wav: (13, 95)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_C_F_044_013.wav: (13, 127)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_C_F_044_014.wav: (13, 189)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_C_F_044_015.wav: (13, 127)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_C_F_044_016.wav: (13, 377)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_C_F_044_017.wav: (13, 127)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_C_F_044_018.wav: (13, 596)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_C_F_044_019.wav: (13, 158)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_C_F_044_020.wav: (13, 64)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_C_F_044_021.wav: (13, 158)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_C_F_044_022.wav: (13, 95)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_C_F_044_023.wav: (13, 130)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_C_F_044_024.wav: (13, 95)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_C_F_044_025.wav: (13, 158)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_C_F_044_026.wav: (13, 127)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_C_F_044_027.wav: (13, 95)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_C_F_044_028.wav: (13, 245)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_C_F_049_001.wav: (13, 144)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_C_F_049_002.wav: (13, 158)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_C_F_050_001.wav: (13, 95)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_C_F_051_001.wav: (13, 127)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_C_F_051_002.wav: (13, 189)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_C_F_051_003.wav: (13, 220)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_C_F_052_001.wav: (13, 277)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_C_M_001_001.wav: (13, 375)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_C_M_001_002.wav: (13, 283)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_C_M_001_003.wav: (13, 439)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_C_M_001_004.wav: (13, 220)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_C_M_001_005.wav: (13, 346)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_C_M_001_006.wav: (13, 438)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_C_M_001_008.wav: (13, 283)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_C_M_001_009.wav: (13, 307)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_C_M_001_010.wav: (13, 220)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_C_M_001_011.wav: (13, 189)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_C_M_001_012.wav: (13, 314)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_C_M_001_013.wav: (13, 408)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_C_M_001_014.wav: (13, 439)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_C_M_001_015.wav: (13, 152)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_C_M_001_016.wav: (13, 252)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_C_M_001_017.wav: (13, 377)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_C_M_001_018.wav: (13, 471)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_C_M_001_019.wav: (13, 439)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_C_M_001_020.wav: (13, 124)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_C_M_001_021.wav: (13, 314)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_C_M_001_022.wav: (13, 187)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_C_M_001_023.wav: (13, 439)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_C_M_001_024.wav: (13, 502)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_C_M_001_025.wav: (13, 377)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_C_M_001_026.wav: (13, 377)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_C_M_001_027.wav: (13, 93)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_C_M_001_028.wav: (13, 220)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_C_M_001_029.wav: (13, 314)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_C_M_001_030.wav: (13, 61)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_C_M_001_031.wav: (13, 189)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_C_M_001_032.wav: (13, 314)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_C_M_001_033.wav: (13, 346)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_C_M_001_034.wav: (13, 252)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_C_M_001_035.wav: (13, 250)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_C_M_001_036.wav: (13, 283)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_C_M_001_037.wav: (13, 158)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_C_M_001_038.wav: (13, 283)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_C_M_001_039.wav: (13, 346)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_C_M_001_040.wav: (13, 220)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_C_M_001_041.wav: (13, 220)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_C_M_001_042.wav: (13, 252)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_C_M_001_043.wav: (13, 346)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_C_M_001_044.wav: (13, 158)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_C_M_001_045.wav: (13, 220)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_C_M_001_046.wav: (13, 189)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_C_M_001_047.wav: (13, 158)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_C_M_001_048.wav: (13, 314)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_C_M_001_049.wav: (13, 156)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_C_M_001_050.wav: (13, 187)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_C_M_001_051.wav: (13, 187)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_C_M_001_052.wav: (13, 304)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_C_M_001_053.wav: (13, 293)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_C_M_001_054.wav: (13, 125)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_C_M_001_055.wav: (13, 218)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_C_M_001_056.wav: (13, 313)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_C_M_001_057.wav: (13, 218)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_C_M_001_058.wav: (13, 125)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_C_M_001_059.wav: (13, 281)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_C_M_001_060.wav: (13, 93)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_C_M_001_061.wav: (13, 93)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_C_M_001_062.wav: (13, 125)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_C_M_001_063.wav: (13, 124)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_C_M_001_064.wav: (13, 187)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_C_M_001_065.wav: (13, 147)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_C_M_001_066.wav: (13, 146)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_C_M_003_001.wav: (13, 217)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_C_M_003_002.wav: (13, 283)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_C_M_003_004.wav: (13, 218)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_C_M_003_005.wav: (13, 218)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_C_M_004_001.wav: (13, 194)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_C_M_004_002.wav: (13, 156)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_C_M_004_003.wav: (13, 187)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_C_M_005_001.wav: (13, 216)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_C_M_005_002.wav: (13, 218)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_C_M_005_003.wav: (13, 93)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_C_M_005_004.wav: (13, 125)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_C_M_005_007.wav: (13, 93)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_C_M_005_008.wav: (13, 124)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_C_M_005_009.wav: (13, 186)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_C_M_006_001.wav: (13, 154)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_C_M_006_002.wav: (13, 217)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_C_M_006_003.wav: (13, 312)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_C_M_006_004.wav: (13, 281)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_C_M_007_001.wav: (13, 249)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_C_M_007_002.wav: (13, 187)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_C_M_007_003.wav: (13, 265)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_C_M_007_004.wav: (13, 93)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_C_M_007_005.wav: (13, 248)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_C_M_007_006.wav: (13, 343)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_C_M_008_001.wav: (13, 218)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_C_M_008_002.wav: (13, 187)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_G_F_002_001.wav: (13, 182)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_G_F_002_002.wav: (13, 249)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_G_F_002_003.wav: (13, 249)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_G_F_002_004.wav: (13, 83)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_G_F_002_005.wav: (13, 31)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_G_F_002_008.wav: (13, 125)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_G_F_002_009.wav: (13, 249)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_G_F_002_014.wav: (13, 218)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_G_F_002_015.wav: (13, 158)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_G_F_002_016.wav: (13, 125)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_G_F_002_017.wav: (13, 97)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_G_F_002_019.wav: (13, 220)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_G_M_002_006.wav: (13, 61)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_G_M_002_007.wav: (13, 156)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_G_M_002_010.wav: (13, 69)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_G_M_002_011.wav: (13, 155)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_G_M_002_012.wav: (13, 199)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_G_M_002_013.wav: (13, 138)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_G_M_002_018.wav: (13, 127)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_G_M_003_003.wav: (13, 125)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_G_M_003_006.wav: (13, 187)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_G_M_003_007.wav: (13, 186)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_G_M_005_005.wav: (13, 281)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_G_M_005_006.wav: (13, 125)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_G_M_011_006.wav: (13, 155)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_G_M_011_008.wav: (13, 61)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_G_M_013_001.wav: (13, 187)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_G_M_013_002.wav: (13, 283)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_G_M_013_003.wav: (13, 158)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_G_M_013_004.wav: (13, 158)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_G_M_013_005.wav: (13, 283)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_G_M_013_006.wav: (13, 64)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_G_M_014_001.wav: (13, 92)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_G_M_014_002.wav: (13, 220)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_G_M_014_003.wav: (13, 220)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_G_M_014_004.wav: (13, 252)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_G_M_014_005.wav: (13, 220)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_G_M_014_006.wav: (13, 377)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_G_M_015_001.wav: (13, 377)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_G_M_015_002.wav: (13, 283)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_G_M_015_003.wav: (13, 189)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_G_M_015_004.wav: (13, 283)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_G_M_015_005.wav: (13, 95)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_G_M_015_006.wav: (13, 189)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_G_M_016_001.wav: (13, 252)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_G_M_016_014.wav: (13, 252)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_G_M_016_015.wav: (13, 377)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_G_M_016_002.wav: (13, 95)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_G_M_016_004.wav: (13, 189)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_G_M_016_005.wav: (13, 220)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_G_M_016_007.wav: (13, 314)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_G_M_016_008.wav: (13, 439)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_G_M_016_009.wav: (13, 377)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_G_M_016_010.wav: (13, 408)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_G_M_016_011.wav: (13, 408)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_G_M_016_012.wav: (13, 409)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_G_M_017_001.wav: (13, 346)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_G_M_017_002.wav: (13, 283)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_G_M_017_003.wav: (13, 221)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_G_M_017_004.wav: (13, 283)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_G_M_017_005.wav: (13, 220)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_G_M_017_007.wav: (13, 127)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_G_M_017_008.wav: (13, 158)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_G_M_017_009.wav: (13, 314)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_G_M_019_003.wav: (13, 346)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_G_M_031_008.wav: (13, 189)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_G_M_038_001.wav: (13, 95)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_G_M_038_002.wav: (13, 158)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_G_M_038_003.wav: (13, 158)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_G_M_038_004.wav: (13, 127)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_G_M_038_005.wav: (13, 158)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_G_M_038_006.wav: (13, 127)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_G_M_038_007.wav: (13, 158)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_G_M_040_004.wav: (13, 189)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_G_M_040_006.wav: (13, 127)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_G_M_040_007.wav: (13, 95)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_G_M_040_008.wav: (13, 95)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_G_M_041_001.wav: (13, 127)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_G_M_041_002.wav: (13, 95)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_G_M_041_003.wav: (13, 158)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_G_M_041_004.wav: (13, 128)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_G_M_041_005.wav: (13, 158)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_P_M_010_001.wav: (13, 91)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_P_M_010_002.wav: (13, 93)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_P_M_010_003.wav: (13, 187)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_P_M_010_004.wav: (13, 312)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_P_M_010_005.wav: (13, 187)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_P_M_010_006.wav: (13, 82)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_P_M_010_007.wav: (13, 187)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_P_M_010_008.wav: (13, 124)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_P_M_010_009.wav: (13, 125)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_P_M_010_010.wav: (13, 156)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_P_M_010_011.wav: (13, 61)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_P_M_010_012.wav: (13, 125)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_P_M_010_013.wav: (13, 93)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_P_M_012_003.wav: (13, 62)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_P_M_012_004.wav: (13, 124)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_P_M_016_006.wav: (13, 283)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_P_M_016_013.wav: (13, 158)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_P_M_017_006.wav: (13, 283)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_P_M_017_010.wav: (13, 307)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_P_M_019_004.wav: (13, 252)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_P_M_019_006.wav: (13, 95)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_P_M_019_009.wav: (13, 158)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_P_M_019_016.wav: (13, 220)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_P_M_019_018.wav: (13, 252)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_P_M_019_020.wav: (13, 127)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_P_M_019_021.wav: (13, 314)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_P_M_019_022.wav: (13, 252)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_P_M_019_023.wav: (13, 252)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_P_M_019_024.wav: (13, 189)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_P_M_019_026.wav: (13, 220)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_P_M_019_030.wav: (13, 220)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_P_M_019_033.wav: (13, 439)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_P_M_019_034.wav: (13, 377)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_P_M_019_035.wav: (13, 252)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_P_M_019_036.wav: (13, 283)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_P_M_019_037.wav: (13, 220)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_P_M_019_038.wav: (13, 743)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_P_M_019_040.wav: (13, 346)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_P_M_019_042.wav: (13, 252)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_P_M_019_043.wav: (13, 158)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_P_M_019_045.wav: (13, 291)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_P_M_019_046.wav: (13, 158)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_P_M_019_047.wav: (13, 346)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_P_M_019_048.wav: (13, 158)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_P_M_019_049.wav: (13, 314)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_P_M_019_050.wav: (13, 283)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_P_M_019_051.wav: (13, 314)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_P_M_019_053.wav: (13, 283)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_P_M_019_054.wav: (13, 314)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_P_M_019_055.wav: (13, 314)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_P_M_019_056.wav: (13, 158)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_P_M_020_001.wav: (13, 251)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_P_M_020_002.wav: (13, 189)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_P_M_020_003.wav: (13, 158)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_P_M_020_004.wav: (13, 377)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_P_M_020_005.wav: (13, 314)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_P_M_020_008.wav: (13, 527)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_P_M_020_009.wav: (13, 346)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_P_M_020_010.wav: (13, 220)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_P_M_020_012.wav: (13, 220)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_P_M_020_014.wav: (13, 127)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_P_M_020_015.wav: (13, 346)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_P_M_020_016.wav: (13, 439)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_P_M_020_017.wav: (13, 377)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_P_M_020_018.wav: (13, 283)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_P_M_020_019.wav: (13, 252)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_P_M_020_020.wav: (13, 201)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_P_M_020_021.wav: (13, 220)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_P_M_020_022.wav: (13, 189)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_P_M_020_024.wav: (13, 285)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_P_M_020_025.wav: (13, 220)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_P_M_020_026.wav: (13, 220)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_P_M_020_027.wav: (13, 252)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_P_M_020_028.wav: (13, 283)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_P_M_020_029.wav: (13, 314)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_P_M_020_030.wav: (13, 314)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_P_M_020_031.wav: (13, 206)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_P_M_020_032.wav: (13, 252)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_P_M_021_001.wav: (13, 260)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_P_M_021_002.wav: (13, 502)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_P_M_021_003.wav: (13, 439)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_P_M_021_004.wav: (13, 346)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_P_M_021_006.wav: (13, 314)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_P_M_021_007.wav: (13, 283)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_P_M_021_008.wav: (13, 252)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_P_M_021_010.wav: (13, 189)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_P_M_021_012.wav: (13, 252)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_P_M_021_013.wav: (13, 314)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_P_M_021_014.wav: (13, 220)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_P_M_022_001.wav: (13, 377)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_P_M_022_003.wav: (13, 252)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_P_M_022_007.wav: (13, 189)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_P_M_022_008.wav: (13, 220)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_P_M_022_009.wav: (13, 127)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_P_M_022_012.wav: (13, 158)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_P_M_022_015.wav: (13, 158)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_P_M_024_001.wav: (13, 155)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_P_M_024_002.wav: (13, 189)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_P_M_025_002.wav: (13, 439)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_P_M_026_001.wav: (13, 220)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_P_M_026_002.wav: (13, 220)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_P_M_026_003.wav: (13, 127)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_P_M_026_005.wav: (13, 252)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_P_M_026_009.wav: (13, 283)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_P_M_028_005.wav: (13, 189)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_P_M_029_001.wav: (13, 127)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_P_M_029_002.wav: (13, 220)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_P_M_029_003.wav: (13, 252)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_P_M_029_004.wav: (13, 158)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_P_M_029_005.wav: (13, 127)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_P_M_030_001.wav: (13, 346)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_P_M_031_001.wav: (13, 189)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_P_M_031_002.wav: (13, 346)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_P_M_031_004.wav: (13, 220)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_P_M_032_001.wav: (13, 283)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_P_M_032_002.wav: (13, 158)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_P_M_034_001.wav: (13, 408)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_P_M_035_002.wav: (13, 283)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_R_F_026_004.wav: (13, 252)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_R_F_026_006.wav: (13, 189)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_R_M_008_003.wav: (13, 334)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_R_M_009_001.wav: (13, 218)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_R_M_009_002.wav: (13, 187)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_R_M_009_005.wav: (13, 143)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_R_M_009_006.wav: (13, 171)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_R_M_009_011.wav: (13, 155)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_R_M_009_016.wav: (13, 249)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_R_M_012_001.wav: (13, 155)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_R_M_012_002.wav: (13, 218)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_R_M_016_003.wav: (13, 64)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_R_M_019_001.wav: (13, 282)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_R_M_019_002.wav: (13, 439)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_R_M_019_005.wav: (13, 314)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_R_M_019_007.wav: (13, 346)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_R_M_019_008.wav: (13, 220)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_R_M_019_010.wav: (13, 792)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_R_M_019_011.wav: (13, 283)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_R_M_019_012.wav: (13, 189)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_R_M_019_013.wav: (13, 283)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_R_M_019_014.wav: (13, 231)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_R_M_019_015.wav: (13, 283)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_R_M_019_019.wav: (13, 220)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_R_M_019_025.wav: (13, 314)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_R_M_019_027.wav: (13, 220)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_R_M_019_028.wav: (13, 158)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_R_M_019_029.wav: (13, 252)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_R_M_019_031.wav: (13, 377)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_R_M_019_032.wav: (13, 252)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_R_M_019_039.wav: (13, 439)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_R_M_019_041.wav: (13, 533)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_R_M_019_044.wav: (13, 346)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_R_M_019_052.wav: (13, 95)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_R_M_019_057.wav: (13, 220)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_R_M_020_006.wav: (13, 127)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_R_M_020_007.wav: (13, 158)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_R_M_020_011.wav: (13, 189)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_R_M_021_005.wav: (13, 220)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_R_M_021_009.wav: (13, 95)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_R_M_021_011.wav: (13, 220)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_R_M_021_015.wav: (13, 314)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_R_M_022_002.wav: (13, 158)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_R_M_022_004.wav: (13, 220)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_R_M_022_005.wav: (13, 283)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_R_M_022_006.wav: (13, 346)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_R_M_022_010.wav: (13, 189)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_R_M_022_011.wav: (13, 189)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_R_M_022_013.wav: (13, 165)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_R_M_022_014.wav: (13, 346)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_R_M_022_016.wav: (13, 439)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_R_M_022_017.wav: (13, 283)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_R_M_022_018.wav: (13, 283)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_R_M_022_019.wav: (13, 176)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_R_M_022_020.wav: (13, 127)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_R_M_022_021.wav: (13, 220)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_R_M_022_022.wav: (13, 158)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_R_M_022_023.wav: (13, 353)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_R_M_022_024.wav: (13, 252)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_R_M_022_025.wav: (13, 346)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_R_M_022_026.wav: (13, 307)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_R_M_023_001.wav: (13, 281)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_R_M_023_002.wav: (13, 252)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_R_M_024_003.wav: (13, 95)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_R_M_024_004.wav: (13, 158)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_R_M_025_001.wav: (13, 314)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_R_M_027_001.wav: (13, 252)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_R_M_027_002.wav: (13, 127)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_R_M_027_003.wav: (13, 283)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_R_M_027_004.wav: (13, 314)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_R_M_027_005.wav: (13, 314)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_R_M_027_006.wav: (13, 220)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_R_M_027_007.wav: (13, 127)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_R_M_028_002.wav: (13, 439)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_R_M_028_003.wav: (13, 127)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_R_M_028_004.wav: (13, 183)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_R_M_028_006.wav: (13, 220)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_R_M_028_007.wav: (13, 95)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_R_M_028_008.wav: (13, 314)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_R_M_028_010.wav: (13, 158)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_R_M_028_011.wav: (13, 213)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_R_M_028_012.wav: (13, 252)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_R_M_030_002.wav: (13, 64)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_R_M_030_003.wav: (13, 189)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_R_M_030_004.wav: (13, 64)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_R_M_030_005.wav: (13, 283)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_R_M_030_006.wav: (13, 189)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_R_M_030_007.wav: (13, 158)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_R_M_030_008.wav: (13, 189)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_R_M_031_005.wav: (13, 220)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_R_M_031_006.wav: (13, 283)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_C_M_008_003.wav: (13, 343)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_C_M_009_004.wav: (13, 124)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_C_M_009_007.wav: (13, 200)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_C_M_009_008.wav: (13, 219)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_C_M_009_009.wav: (13, 217)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_C_M_009_010.wav: (13, 60)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_C_M_009_012.wav: (13, 249)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_C_M_009_013.wav: (13, 155)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_C_M_009_014.wav: (13, 153)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_C_M_009_015.wav: (13, 156)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_C_M_009_017.wav: (13, 186)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_C_M_009_018.wav: (13, 125)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_C_M_009_019.wav: (13, 62)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_C_M_009_020.wav: (13, 187)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_C_M_009_021.wav: (13, 92)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_C_M_009_022.wav: (13, 125)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_C_M_011_001.wav: (13, 129)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_C_M_011_002.wav: (13, 89)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_C_M_011_003.wav: (13, 124)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_C_M_011_004.wav: (13, 93)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_C_M_011_005.wav: (13, 218)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_C_M_011_007.wav: (13, 125)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_C_M_012_005.wav: (13, 125)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_C_M_012_006.wav: (13, 218)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_C_M_012_007.wav: (13, 125)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_C_M_012_008.wav: (13, 124)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_C_M_019_017.wav: (13, 189)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_C_M_020_013.wav: (13, 283)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_C_M_031_003.wav: (13, 127)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_C_M_035_003.wav: (13, 189)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_C_M_035_004.wav: (13, 158)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_C_M_040_001.wav: (13, 64)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_C_M_040_002.wav: (13, 127)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_C_M_040_003.wav: (13, 64)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_C_M_040_005.wav: (13, 95)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_C_M_043_001.wav: (13, 87)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_C_M_043_002.wav: (13, 127)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_C_M_043_003.wav: (13, 127)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_C_M_043_004.wav: (13, 224)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_C_M_043_007.wav: (13, 127)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_C_M_045_001.wav: (13, 95)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_C_M_045_002.wav: (13, 127)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_C_M_045_003.wav: (13, 95)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_C_M_045_004.wav: (13, 346)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_C_M_046_001.wav: (13, 158)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_C_M_046_002.wav: (13, 127)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_C_M_046_003.wav: (13, 95)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_C_M_046_004.wav: (13, 294)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_C_M_047_001.wav: (13, 27)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_C_M_047_002.wav: (13, 201)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_C_M_048_001.wav: (13, 95)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_C_M_048_002.wav: (13, 408)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_C_M_048_003.wav: (13, 189)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_C_M_048_004.wav: (13, 346)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_C_M_048_005.wav: (13, 33)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_C_M_048_006.wav: (13, 275)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_C_M_048_007.wav: (13, 344)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_C_M_048_008.wav: (13, 140)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_C_M_048_009.wav: (13, 189)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/H_ML_001_C_M_048_010.wav: (13, 158)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/NH_ML_001_N_M_001_001.wav: (13, 248)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/NH_ML_001_N_M_001_002.wav: (13, 156)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/NH_ML_001_N_M_001_003.wav: (13, 124)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/NH_ML_001_N_M_001_004.wav: (13, 187)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/NH_ML_001_N_M_001_005.wav: (13, 125)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/NH_ML_001_N_M_001_006.wav: (13, 61)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/NH_ML_001_N_M_001_007.wav: (13, 374)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/NH_ML_001_N_M_001_008.wav: (13, 187)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/NH_ML_001_N_M_001_009.wav: (13, 187)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/NH_ML_001_N_M_001_010.wav: (13, 76)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/NH_ML_001_N_M_001_011.wav: (13, 126)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/NH_ML_001_N_M_001_012.wav: (13, 281)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/NH_ML_001_N_M_001_013.wav: (13, 126)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/NH_ML_001_N_M_001_014.wav: (13, 230)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/NH_ML_001_N_M_001_015.wav: (13, 62)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/NH_ML_001_N_M_001_016.wav: (13, 62)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/NH_ML_001_N_M_001_017.wav: (13, 218)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/NH_ML_001_N_M_001_018.wav: (13, 67)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/NH_ML_001_N_M_001_019.wav: (13, 124)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/NH_ML_001_N_M_001_020.wav: (13, 249)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/NH_ML_001_N_M_001_021.wav: (13, 124)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/NH_ML_001_N_M_001_022.wav: (13, 156)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/NH_ML_001_N_M_001_023.wav: (13, 312)
# ...
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/NH_ML_002_N_M_010_009.wav: (13, 189)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/NH_ML_002_N_M_010_010.wav: (13, 220)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/NH_ML_002_N_M_010_011.wav: (13, 283)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/NH_ML_002_N_M_010_012.wav: (13, 346)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/NH_ML_002_N_M_010_013.wav: (13, 189)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/NH_ML_002_N_M_010_014.wav: (13, 346)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/NH_ML_002_N_M_011_001.wav: (13, 309)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/NH_ML_002_N_M_011_002.wav: (13, 220)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/NH_ML_002_N_M_011_003.wav: (13, 189)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/NH_ML_002_N_M_011_004.wav: (13, 158)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/NH_ML_002_N_M_011_005.wav: (13, 220)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/NH_ML_002_N_M_011_006.wav: (13, 220)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/NH_ML_002_N_M_011_007.wav: (13, 220)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/NH_ML_002_N_M_011_008.wav: (13, 189)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/NH_ML_002_N_M_011_009.wav: (13, 377)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/NH_ML_002_N_M_011_010.wav: (13, 346)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/NH_ML_002_N_M_011_011.wav: (13, 189)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/NH_ML_002_N_M_011_012.wav: (13, 220)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/NH_ML_002_N_M_011_013.wav: (13, 189)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/NH_ML_002_N_M_011_014.wav: (13, 252)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/NH_ML_002_N_M_011_015.wav: (13, 283)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/NH_ML_002_N_M_011_016.wav: (13, 283)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/NH_ML_002_N_M_012_001.wav: (13, 247)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/NH_ML_002_N_M_012_002.wav: (13, 283)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/NH_ML_002_N_M_012_003.wav: (13, 158)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/NH_ML_002_N_M_012_004.wav: (13, 408)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/NH_ML_002_N_M_012_005.wav: (13, 252)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/NH_ML_002_N_M_012_006.wav: (13, 375)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/NH_ML_002_N_M_012_007.wav: (13, 307)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/NH_ML_002_N_M_012_008.wav: (13, 252)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/NH_ML_002_N_M_012_009.wav: (13, 189)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/NH_ML_002_N_M_012_010.wav: (13, 220)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/NH_ML_002_N_M_012_011.wav: (13, 220)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/NH_ML_002_N_M_012_012.wav: (13, 219)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/NH_ML_002_N_M_012_013.wav: (13, 252)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/NH_ML_002_N_M_012_014.wav: (13, 252)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/NH_ML_002_N_M_012_015.wav: (13, 252)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/NH_ML_002_N_M_012_016.wav: (13, 252)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/NH_ML_002_N_M_012_017.wav: (13, 314)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/NH_ML_002_N_M_012_018.wav: (13, 213)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/NH_ML_002_N_M_012_019.wav: (13, 220)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/NH_ML_002_N_M_012_020.wav: (13, 283)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/NH_ML_002_N_M_014_001.wav: (13, 214)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/NH_ML_002_N_M_014_002.wav: (13, 377)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/NH_ML_002_N_M_014_003.wav: (13, 189)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/NH_ML_002_N_M_014_004.wav: (13, 220)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/NH_ML_002_N_M_014_005.wav: (13, 252)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/NH_ML_002_N_M_014_006.wav: (13, 314)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/NH_ML_002_N_M_014_007.wav: (13, 189)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/NH_ML_002_N_M_014_008.wav: (13, 314)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/NH_ML_002_N_M_014_009.wav: (13, 189)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/NH_ML_002_N_M_014_010.wav: (13, 189)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/NH_ML_002_N_M_014_011.wav: (13, 252)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/NH_ML_002_N_M_014_012.wav: (13, 252)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/NH_ML_002_N_M_014_013.wav: (13, 314)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/NH_ML_002_N_M_014_014.wav: (13, 252)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/NH_ML_002_N_M_014_015.wav: (13, 283)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/NH_ML_002_N_M_014_016.wav: (13, 377)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/NH_ML_002_N_M_014_017.wav: (13, 283)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/NH_ML_002_N_M_014_018.wav: (13, 220)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/NH_ML_002_N_M_014_019.wav: (13, 220)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/NH_ML_002_N_M_014_020.wav: (13, 252)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/NH_ML_002_N_M_014_021.wav: (13, 346)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/NH_ML_002_N_M_014_022.wav: (13, 377)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/NH_ML_002_N_M_014_023.wav: (13, 252)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/NH_ML_002_N_M_014_024.wav: (13, 377)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/NH_ML_002_N_M_014_025.wav: (13, 189)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/NH_ML_002_N_M_014_026.wav: (13, 314)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/NH_ML_002_N_M_014_027.wav: (13, 314)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/NH_ML_002_N_M_014_028.wav: (13, 189)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/NH_ML_002_N_M_014_029.wav: (13, 377)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/NH_ML_002_N_M_014_030.wav: (13, 252)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/NH_ML_002_N_M_014_031.wav: (13, 252)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/NH_ML_002_N_M_014_032.wav: (13, 314)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/NH_ML_002_N_M_014_033.wav: (13, 408)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/NH_ML_002_N_M_014_034.wav: (13, 184)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/NH_ML_002_N_M_014_035.wav: (13, 273)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/NH_ML_002_N_M_014_036.wav: (13, 158)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/NH_ML_002_N_M_014_037.wav: (13, 252)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/NH_ML_002_N_M_014_038.wav: (13, 314)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/NH_ML_002_N_M_014_039.wav: (13, 283)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/NH_ML_002_N_M_014_040.wav: (13, 314)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/NH_ML_002_N_M_014_041.wav: (13, 283)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/NH_ML_002_N_M_014_042.wav: (13, 346)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/NH_ML_002_N_M_014_043.wav: (13, 283)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/NH_ML_002_N_M_014_044.wav: (13, 252)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/NH_ML_002_N_M_014_045.wav: (13, 314)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/NH_ML_002_N_M_014_046.wav: (13, 220)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/NH_ML_002_N_M_014_047.wav: (13, 314)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/NH_ML_002_N_M_014_048.wav: (13, 346)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/NH_ML_002_N_M_014_049.wav: (13, 252)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/NH_ML_002_N_M_014_050.wav: (13, 314)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/NH_ML_002_N_M_014_051.wav: (13, 220)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/NH_ML_002_N_M_014_052.wav: (13, 189)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/NH_ML_002_N_M_014_053.wav: (13, 252)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/NH_ML_002_N_M_014_054.wav: (13, 189)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/NH_ML_002_N_M_014_055.wav: (13, 189)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/NH_ML_002_N_M_014_056.wav: (13, 220)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/NH_ML_002_N_M_014_057.wav: (13, 346)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/NH_ML_002_N_M_014_058.wav: (13, 220)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/NH_ML_002_N_M_014_059.wav: (13, 127)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/NH_ML_002_N_M_014_060.wav: (13, 346)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/NH_ML_002_N_M_014_061.wav: (13, 252)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/NH_ML_002_N_M_014_062.wav: (13, 220)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/NH_ML_002_N_M_014_063.wav: (13, 314)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/NH_ML_002_N_M_014_064.wav: (13, 189)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/NH_ML_002_N_M_014_065.wav: (13, 158)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/NH_ML_002_N_M_014_066.wav: (13, 283)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/NH_ML_002_N_M_014_067.wav: (13, 189)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/NH_ML_002_N_M_014_068.wav: (13, 283)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/NH_ML_002_N_M_014_069.wav: (13, 189)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/NH_ML_002_N_M_014_070.wav: (13, 174)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/NH_ML_002_N_M_014_071.wav: (13, 311)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/NH_ML_002_N_M_014_072.wav: (13, 189)
# MFCC shape for /content/drive/MyDrive/Project/Malayam/audio/NH_ML_002_N_M_014_073.wav: (13, 283)
# Class weights: {0: 0.9494623655913978, 1: 2.153658536585366, 2: 0.4349753694581281, 3: 1.4966101694915255, 4: 1.9406593406593406}
# Model trained successfully.
# MFCC shape for //content/drive/MyDrive/Project/Test/Malayalam/audio/ML_TE_001.wav: (13, 127)
# MFCC shape for //content/drive/MyDrive/Project/Test/Malayalam/audio/ML_TE_002.wav: (13, 220)
# MFCC shape for //content/drive/MyDrive/Project/Test/Malayalam/audio/ML_TE_003.wav: (13, 189)
# MFCC shape for //content/drive/MyDrive/Project/Test/Malayalam/audio/ML_TE_004.wav: (13, 158)
# MFCC shape for //content/drive/MyDrive/Project/Test/Malayalam/audio/ML_TE_005.wav: (13, 220)
# MFCC shape for //content/drive/MyDrive/Project/Test/Malayalam/audio/ML_TE_006.wav: (13, 189)
# MFCC shape for //content/drive/MyDrive/Project/Test/Malayalam/audio/ML_TE_007.wav: (13, 377)
# MFCC shape for //content/drive/MyDrive/Project/Test/Malayalam/audio/ML_TE_008.wav: (13, 95)
# MFCC shape for //content/drive/MyDrive/Project/Test/Malayalam/audio/ML_TE_009.wav: (13, 127)
# MFCC shape for //content/drive/MyDrive/Project/Test/Malayalam/audio/ML_TE_010.wav: (13, 95)
# MFCC shape for //content/drive/MyDrive/Project/Test/Malayalam/audio/ML_TE_11.wav: (13, 158)
# MFCC shape for //content/drive/MyDrive/Project/Test/Malayalam/audio/ML_TE_12.wav: (13, 496)
# MFCC shape for //content/drive/MyDrive/Project/Test/Malayalam/audio/ML_TE_13.wav: (13, 158)
# MFCC shape for //content/drive/MyDrive/Project/Test/Malayalam/audio/ML_TE_14.wav: (13, 95)
# MFCC shape for //content/drive/MyDrive/Project/Test/Malayalam/audio/ML_TE_15.wav: (13, 158)
# MFCC shape for //content/drive/MyDrive/Project/Test/Malayalam/audio/ML_TE_16.wav: (13, 127)
# MFCC shape for //content/drive/MyDrive/Project/Test/Malayalam/audio/ML_TE_17.wav: (13, 95)
# MFCC shape for //content/drive/MyDrive/Project/Test/Malayalam/audio/ML_TE_18.wav: (13, 158)
# MFCC shape for //content/drive/MyDrive/Project/Test/Malayalam/audio/ML_TE_19.wav: (13, 95)
# MFCC shape for //content/drive/MyDrive/Project/Test/Malayalam/audio/ML_TE_20.wav: (13, 95)
# MFCC shape for //content/drive/MyDrive/Project/Test/Malayalam/audio/ML_TE_21.wav: (13, 252)
# MFCC shape for //content/drive/MyDrive/Project/Test/Malayalam/audio/ML_TE_22.wav: (13, 189)
# MFCC shape for //content/drive/MyDrive/Project/Test/Malayalam/audio/ML_TE_23.wav: (13, 158)
# MFCC shape for //content/drive/MyDrive/Project/Test/Malayalam/audio/ML_TE_24.wav: (13, 220)
# MFCC shape for //content/drive/MyDrive/Project/Test/Malayalam/audio/ML_TE_25.wav: (13, 189)
# MFCC shape for //content/drive/MyDrive/Project/Test/Malayalam/audio/ML_TE_26.wav: (13, 128)
# MFCC shape for //content/drive/MyDrive/Project/Test/Malayalam/audio/ML_TE_27.wav: (13, 188)
# MFCC shape for //content/drive/MyDrive/Project/Test/Malayalam/audio/ML_TE_28.wav: (13, 434)
# MFCC shape for //content/drive/MyDrive/Project/Test/Malayalam/audio/ML_TE_29.wav: (13, 64)
# MFCC shape for //content/drive/MyDrive/Project/Test/Malayalam/audio/ML_TE_30.wav: (13, 189)
# MFCC shape for //content/drive/MyDrive/Project/Test/Malayalam/audio/ML_TE_31.wav: (13, 189)
# MFCC shape for //content/drive/MyDrive/Project/Test/Malayalam/audio/ML_TE_32.wav: (13, 220)
# MFCC shape for //content/drive/MyDrive/Project/Test/Malayalam/audio/ML_TE_33.wav: (13, 189)
# MFCC shape for //content/drive/MyDrive/Project/Test/Malayalam/audio/ML_TE_34.wav: (13, 314)
# MFCC shape for //content/drive/MyDrive/Project/Test/Malayalam/audio/ML_TE_35.wav: (13, 658)
# MFCC shape for //content/drive/MyDrive/Project/Test/Malayalam/audio/ML_TE_36.wav: (13, 189)
# MFCC shape for //content/drive/MyDrive/Project/Test/Malayalam/audio/ML_TE_37.wav: (13, 188)
# MFCC shape for //content/drive/MyDrive/Project/Test/Malayalam/audio/ML_TE_38.wav: (13, 158)
# MFCC shape for //content/drive/MyDrive/Project/Test/Malayalam/audio/ML_TE_39.wav: (13, 95)
# MFCC shape for //content/drive/MyDrive/Project/Test/Malayalam/audio/ML_TE_40.wav: (13, 158)
# MFCC shape for //content/drive/MyDrive/Project/Test/Malayalam/audio/ML_TE_41.wav: (13, 829)
# MFCC shape for //content/drive/MyDrive/Project/Test/Malayalam/audio/ML_TE_42.wav: (13, 637)
# MFCC shape for //content/drive/MyDrive/Project/Test/Malayalam/audio/ML_TE_43.wav: (13, 658)
# MFCC shape for //content/drive/MyDrive/Project/Test/Malayalam/audio/ML_TE_44.wav: (13, 346)
# MFCC shape for //content/drive/MyDrive/Project/Test/Malayalam/audio/ML_TE_45.wav: (13, 836)
# MFCC shape for //content/drive/MyDrive/Project/Test/Malayalam/audio/ML_TE_46.wav: (13, 283)
# MFCC shape for //content/drive/MyDrive/Project/Test/Malayalam/audio/ML_TE_47.wav: (13, 439)
# MFCC shape for //content/drive/MyDrive/Project/Test/Malayalam/audio/ML_TE_48.wav: (13, 220)
# MFCC shape for //content/drive/MyDrive/Project/Test/Malayalam/audio/ML_TE_49.wav: (13, 346)
# MFCC shape for //content/drive/MyDrive/Project/Test/Malayalam/audio/ML_TE_50.wav: (13, 252)
# Predictions saved to Random_audio_predictions.tsv.

# %% [markdown]
# **MLP classifier**

# %%
import pandas as pd
import librosa
import numpy as np
import os
from sklearn.neural_network import MLPClassifier
from sklearn.preprocessing import LabelEncoder
from sklearn.utils.class_weight import compute_class_weight

# Paths (update with actual paths)
train_csv_path = "/content/drive/MyDrive/Project/Malayam/ML-AT-train.csv"
train_audio_dir = "/content/drive/MyDrive/Project/Malayam/audio"  # Corrected path
test_audio_dir = "/content/drive/MyDrive/Project/Test/Malayalam/audio"  # Corrected path
output_tsv_path = "MLP_audio_predictions.tsv"  # Change path as needed

# Step 1: Load train.csv to map class labels
train_df = pd.read_csv(train_csv_path)
train_df['Class Label Short'] = train_df['Class Label Short'].astype(str)

# Step 2: Preprocessing Malayalam audio (MFCC feature extraction)
def preprocess_audio(file_path, sr=16000):
    try:
        y, original_sr = librosa.load(file_path, sr=None)
        # Resample if necessary
        if original_sr != sr:
            y = librosa.resample(y, orig_sr=original_sr, target_sr=sr)
        # Trim silence from audio
        y, _ = librosa.effects.trim(y)
        # Extract MFCC (Mel Frequency Cepstral Coefficients)
        mfccs = librosa.feature.mfcc(y=y, sr=sr, n_mfcc=13)
        return np.mean(mfccs, axis=1)
    except Exception as e:
        print(f"Error processing file {file_path}: {e}")
        return None

# Step 3: Extract features and labels for training
X_train, y_train = [], []
for _, row in train_df.iterrows():
    file_path = os.path.join(train_audio_dir, row['File Name'] + ".wav" )  # Add .wav extension
    if os.path.exists(file_path):
        features = preprocess_audio(file_path)
        if features is not None:
            X_train.append(features)
            y_train.append(row['Class Label Short'])
        else:
            print(f"Skipping file {file_path} due to feature extraction failure.")
    else:
        print(f"File not found: {file_path}")

X_train = np.array(X_train)

# Check if X_train is empty
if X_train.size == 0:
    print("No valid training data found. Please check file paths and data.")
else:
    # Proceed with model training
    label_encoder = LabelEncoder()
    y_train_encoded = label_encoder.fit_transform(y_train)

    # Step 4: Compute class weights
    class_weights = compute_class_weight(
        class_weight="balanced",
        classes=np.unique(y_train_encoded),
        y=y_train_encoded
    )
    class_weight_dict = {i: weight for i, weight in enumerate(class_weights)}
    print(f"Class weights: {class_weight_dict}")

    # Step 5: Train MLPClassifier
    clf = MLPClassifier(
        hidden_layer_sizes=(128, 64),
        activation='relu',
        solver='adam',
        max_iter=200,
        random_state=42
    )
    clf.fit(X_train, y_train_encoded)
    print("MLPClassifier trained successfully.")

# Step 6: Predict for test data
test_predictions = []
test_files = [f for f in os.listdir(test_audio_dir) if f.endswith('.wav')]
for file_name in test_files:
    file_path = os.path.join(test_audio_dir, file_name)
    features = preprocess_audio(file_path)
    if features is not None:
        predicted_label_encoded = clf.predict([features])
        predicted_label = label_encoder.inverse_transform(predicted_label_encoded)[0]
        test_predictions.append({"File_Name": file_name, "predicted_label": predicted_label})
    else:
        print(f"Skipping file {file_path} due to feature extraction failure.")

# Step 7: Save predictions to a TSV file
test_predictions_df = pd.DataFrame(test_predictions)
test_predictions_df.to_csv(output_tsv_path, sep="\t", index=False)
print(f"Predictions saved to {output_tsv_path}.")
# Out:
# Class weights: {0: 0.9494623655913978, 1: 2.153658536585366, 2: 0.4349753694581281, 3: 1.4966101694915255, 4: 1.9406593406593406}
# /usr/local/lib/python3.11/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# MLPClassifier trained successfully.
# Predictions saved to MLP_audio_predictions.tsv.

# %% [markdown]
# **SVM**

# %%
import pandas as pd
import librosa
import numpy as np
import os
from sklearn.svm import SVC
from sklearn.preprocessing import LabelEncoder
from sklearn.utils.class_weight import compute_class_weight

# Paths (update with actual paths)
train_csv_path = "/content/drive/MyDrive/Project/Malayam/ML-AT-train.csv"
train_audio_dir = "/content/drive/MyDrive/Project/Malayam/audio"  # Corrected path
test_audio_dir = "/content/drive/MyDrive/Project/Test/Malayalam/audio"  # Corrected path
output_tsv_path = "SVM_audio_predictions.tsv"  # Change path as needed

# Step 1: Load train.csv to map class labels
train_df = pd.read_csv(train_csv_path)
train_df['Class Label Short'] = train_df['Class Label Short'].astype(str)

# Step 2: Preprocessing Malayalam audio (MFCC feature extraction)
def preprocess_audio(file_path, sr=16000):
    try:
        y, original_sr = librosa.load(file_path, sr=None)
        # Resample if necessary
        if original_sr != sr:
            y = librosa.resample(y, orig_sr=original_sr, target_sr=sr)
        # Trim silence from audio
        y, _ = librosa.effects.trim(y)
        # Extract MFCC (Mel Frequency Cepstral Coefficients)
        mfccs = librosa.feature.mfcc(y=y, sr=sr, n_mfcc=13)
        return np.mean(mfccs, axis=1)
    except Exception as e:
        print(f"Error processing file {file_path}: {e}")
        return None

# Step 3: Extract features and labels for training
X_train, y_train = [], []
for _, row in train_df.iterrows():
    file_path = os.path.join(train_audio_dir, row['File Name'] + ".wav")  # Add .wav extension
    if os.path.exists(file_path):
        features = preprocess_audio(file_path)
        if features is not None:
            X_train.append(features)
            y_train.append(row['Class Label Short'])
        else:
            print(f"Skipping file {file_path} due to feature extraction failure.")
    else:
        print(f"File not found: {file_path}")

X_train = np.array(X_train)

# Check if X_train is empty
if X_train.size == 0:
    print("No valid training data found. Please check file paths and data.")
else:
    # Proceed with model training
    label_encoder = LabelEncoder()
    y_train_encoded = label_encoder.fit_transform(y_train)

    # Step 4: Compute class weights
    class_weights = compute_class_weight(
        class_weight="balanced",
        classes=np.unique(y_train_encoded),
        y=y_train_encoded
    )
    class_weight_dict = {i: weight for i, weight in enumerate(class_weights)}
    print(f"Class weights: {class_weight_dict}")

    # Step 5: Train SVM Classifier
    clf = SVC(
        kernel='rbf',  # Radial Basis Function kernel
        C=1.0,  # Regularization parameter
        class_weight=class_weight_dict,
        probability=True  # Enable probability estimates
    )
    clf.fit(X_train, y_train_encoded)
    print("SVM trained successfully.")

# Step 6: Predict for test data
test_predictions = []
test_files = [f for f in os.listdir(test_audio_dir) if f.endswith('.wav')]
for file_name in test_files:
    file_path = os.path.join(test_audio_dir, file_name)
    features = preprocess_audio(file_path)
    if features is not None:
        predicted_label_encoded = clf.predict([features])
        predicted_label = label_encoder.inverse_transform(predicted_label_encoded)[0]
        test_predictions.append({"File_Name": file_name, "predicted_label": predicted_label})
    else:
        print(f"Skipping file {file_path} due to feature extraction failure.")

# Step 7: Save predictions to a TSV file
test_predictions_df = pd.DataFrame(test_predictions)
test_predictions_df.to_csv(output_tsv_path, sep="\t", index=False)
print(f"Predictions saved to {output_tsv_path}.")
# Out:
# Class weights: {0: 0.9494623655913978, 1: 2.153658536585366, 2: 0.4349753694581281, 3: 1.4966101694915255, 4: 1.9406593406593406}
# SVM trained successfully.
# Predictions saved to SVM_audio_predictions.tsv.

# %%
import pandas as pd

# Load the TSV file
file_path = "/content/Random_audio_predictions.tsv"
df = pd.read_csv(file_path, sep="\t")

# Remove the '.wav' extension from the 'filename' column
df['File_Name'] = df['File_Name'].str.replace('.wav', '', regex=False)

# Save the updated DataFrame back to a new TSV file
output_path = "/content/Random_audio_predictions.tsv"
df.to_csv(output_path, sep="\t", index=False)

print(f"Updated file saved to {output_path}")
# Out:
# Updated file saved to /content/Random_audio_predictions.tsv

# %% [markdown]
# **Fusion with weight**

# %%
import pandas as pd
from collections import Counter

# File paths (update if necessary)
svm_predictions_path = "/content/SVM_audio_predictions.tsv"
mlp_predictions_path = "/content/MLP_audio_predictions.tsv"
rf_predictions_path = "/content/Random_audio_predictions.tsv"  # New file
output_fused_predictions_path ="/content/Audio_fusion_weight.tsv"


# Load predictions
svm_predictions = pd.read_csv(svm_predictions_path, sep="\t")
mlp_predictions = pd.read_csv(mlp_predictions_path, sep="\t")
rf_predictions = pd.read_csv(rf_predictions_path, sep="\t")  # Load additional predictions

# Ensure all files have the same filenames in the same order
if not (
    all(svm_predictions['File_Name'] == mlp_predictions['File_Name']) and
    all(svm_predictions['File_Name'] == rf_predictions['File_Name'])
):
    raise ValueError("Mismatch in filenames between the prediction files.")

# Majority fusion with different weights
fused_predictions = []
for _, (svm_row, mlp_row, rf_row) in enumerate(zip(
    svm_predictions.itertuples(),
    mlp_predictions.itertuples(),
    rf_predictions.itertuples()
)):
    File_Name = svm_row.File_Name
    svm_label = svm_row.predicted_label
    mlp_label = mlp_row.predicted_label
    rf_label = rf_row.predicted_label  # Additional model prediction

    # Weighted voting
    vote_counter = Counter()
    vote_counter[svm_label] += 1
    vote_counter[mlp_label] += 3
    vote_counter[rf_label] += 2

    # Majority vote
    fused_label = vote_counter.most_common(1)[0][0]
    fused_predictions.append({"File_Name": File_Name, "fused_label": fused_label})

# Save fused predictions to a new TSV file
fused_predictions_df = pd.DataFrame(fused_predictions)
fused_predictions_df.to_csv(output_fused_predictions_path, sep="\t", index=False)
print(f"Fused predictions saved to {output_fused_predictions_path}.")
# Out:
# Fused predictions saved to /content/Audio_fusion_weight.tsv.

# %% [markdown]
# **Fusion without weight**

# %%
import pandas as pd
from collections import Counter

# File paths (update if necessary)
svm_predictions_path = "/content/SVM_audio_predictions.tsv"
mlp_predictions_path = "/content/MLP_audio_predictions.tsv"
rf_predictions_path = "/content/Random_audio_predictions.tsv"  # New file
output_fused_predictions_path = "/content/Fused_prediction_Audio.tsv"

# Load predictions
svm_predictions = pd.read_csv(svm_predictions_path, sep="\t")
mlp_predictions = pd.read_csv(mlp_predictions_path, sep="\t")
rf_predictions = pd.read_csv(rf_predictions_path, sep="\t")  # Load additional predictions

# Ensure all files have the same filenames in the same order
if not (
    all(svm_predictions['File_Name'] == mlp_predictions['File_Name']) and
    all(svm_predictions['File_Name'] == rf_predictions['File_Name'])
):
    raise ValueError("Mismatch in filenames between the prediction files.")

# Majority fusion without weighting
fused_predictions = []
for _, (svm_row, mlp_row, rf_row) in enumerate(zip(
    svm_predictions.itertuples(),
    mlp_predictions.itertuples(),
    rf_predictions.itertuples()
)):
    File_Name = svm_row.File_Name
    svm_label = svm_row.predicted_label
    mlp_label = mlp_row.predicted_label
    rf_label = rf_row.predicted_label

    # Equal voting
    vote_counter = Counter([svm_label, mlp_label, rf_label])

    # Majority vote
    fused_label = vote_counter.most_common(1)[0][0]
    fused_predictions.append({"File_Name": File_Name, "fused_label": fused_label})

# Save fused predictions to a new TSV file
fused_predictions_df = pd.DataFrame(fused_predictions)
fused_predictions_df.to_csv(output_fused_predictions_path, sep="\t", index=False)
print(f"Fused predictions saved to {output_fused_predictions_path}.")
# Out:
# Fused predictions saved to /content/Fused_prediction_Audio.tsv.

# %%
# Convert filename column to uppercase
fused_predictions_df['File_Name'] = fused_predictions_df['File_Name'].str.upper()

# Save the updated file
output_fused_file = "/content/SSNCSE_Malayalam_Run1.tsv"
fused_predictions_df.to_csv(output_fused_file, sep="\t", index=False)

print(f"Updated fused predictions saved to {output_fused_file}.")
# Out:
# Updated fused predictions saved to /content/SSNCSE_Malayalam_Run1.tsv.

# %% [markdown]
# #Final (Text+Audio)

# %% [markdown]
# **Fusion with weight**

# %%
import pandas as pd
from collections import Counter

# File paths (update if necessary)
text_predictions_path = "/content/Text_fusion_weight.tsv"
audio_predictions_path = "/content/Audio_fusion_weight.tsv" # New file

# Load predictions
text_predictions = pd.read_csv(text_predictions_path, sep="\t")
audio_predictions = pd.read_csv(audio_predictions_path, sep="\t")


# Trim whitespace and ensure lowercase filenames for consistency
text_predictions['File_Name'] = text_predictions['File_Name'].str.strip().str.lower()
audio_predictions['File_Name'] = audio_predictions['File_Name'].str.strip().str.lower()

# Get unique filenames from both files
text_filenames = set(text_predictions['File_Name'])
audio_filenames = set(audio_predictions['File_Name'])

# Find mismatches
only_in_text = text_filenames - audio_filenames
only_in_audio = audio_filenames - text_filenames

# Print differences
print(f"Filenames only in text predictions: {only_in_text}")
print(f"Filenames only in audio predictions: {only_in_audio}")

# Keep only common filenames
common_filenames = text_filenames & audio_filenames

# Filter both DataFrames to keep only common filenames
text_predictions = text_predictions[text_predictions['File_Name'].isin(common_filenames)]
audio_predictions = audio_predictions[audio_predictions['File_Name'].isin(common_filenames)]

# Sort and reset index to align both files properly
text_predictions = text_predictions.sort_values(by='File_Name').reset_index(drop=True)
audio_predictions = audio_predictions.sort_values(by='File_Name').reset_index(drop=True)

# Define weights (adjust as needed)
weight_text = 1
weight_audio = 2

fused_predictions = []
for _, (text_row, audio_row) in enumerate(zip(text_predictions.itertuples(), audio_predictions.itertuples())):
    File_Name = text_row.File_Name
    text_label = text_row.fused_label
    audio_label = audio_row.fused_label

    # Weighted vote counting
    vote_counter = Counter()
    vote_counter[text_label] += weight_text
    vote_counter[audio_label] += weight_audio

    # Select the label with the highest weight
    fused_label = vote_counter.most_common(1)[0][0]
    fused_predictions.append({"File_Name": File_Name, "fused_label": fused_label})

# Save to TSV file
fused_predictions_df = pd.DataFrame(fused_predictions)
output_fused_file = "/content/SSNCSE_Malayalam_Run1.tsv"
fused_predictions_df.to_csv(output_fused_file, sep="\t", index=False)

print(f"Final fused predictions saved to {output_fused_file}.")
# Out:
# Filenames only in text predictions: set()
# Filenames only in audio predictions: set()
# Final fused predictions saved to /content/SSNCSE_Malayalam_Run1.tsv.

# %%
from sklearn.metrics import classification_report
import pandas as pd
from sklearn.preprocessing import LabelEncoder

# Load the true labels from the Excel file (Sheet1)
true_labels_file = "/content/ML-AT-test.xlsx - Sheet1.tsv"
true_labels_data = pd.read_csv(true_labels_file, sep='\t')

# Load the predicted labels from the TSV file
predicted_labels_file = "/content/SSNCSE_MAlayalam_Run1.tsv"
predicted_data = pd.read_csv(predicted_labels_file, sep='\t')

# Ensure both datasets have the same 'File Name' column for alignment
# Remove leading/trailing spaces from all column names
true_labels_data.columns = true_labels_data.columns.str.strip()

# Now merge the datasets using the cleaned column names
merged_data = pd.merge(true_labels_data[['File_Name', 'Class Label']],
                       predicted_data[['File_Name', 'fused_label']],
                       on='File_Name')

# Extract true labels and predicted labels
y_true = merged_data['Class Label']
y_pred = merged_data['fused_label']

# Continue with the rest of your code...
# Encode the true and predicted labels (if needed)
label_encoder = LabelEncoder()
y_true_encoded = label_encoder.fit_transform(y_true)
y_pred_encoded = label_encoder.transform(y_pred)

# Generate the classification report
print(classification_report(y_true_encoded, y_pred_encoded, target_names=label_encoder.classes_))
# Out:
#               precision    recall  f1-score   support
#
#            C       0.64      0.70      0.67        10
#            G       0.55      0.60      0.57        10
#            N       0.53      1.00      0.69        10
#            P       0.50      0.30      0.38        10
#            R       0.67      0.20      0.31        10
#
#     accuracy                           0.56        50
#    macro avg       0.57      0.56      0.52        50
# weighted avg       0.57      0.56      0.52        50

# %% [markdown]
# **Fusion without weight**

# %%
import pandas as pd
from collections import Counter

# File paths (update if necessary)
text_predictions_path = "/content/Text_fusion.tsv"
audio_predictions_path = "/content/Fused_prediction_Audio.tsv"  # New file

# Load predictions
text_predictions = pd.read_csv(text_predictions_path, sep="\t")
audio_predictions = pd.read_csv(audio_predictions_path, sep="\t")

# Trim whitespace and ensure lowercase filenames for consistency
text_predictions['File_Name'] = text_predictions['File_Name'].str.strip().str.lower()
audio_predictions['File_Name'] = audio_predictions['File_Name'].str.strip().str.lower()

# Get unique filenames from both files
text_filenames = set(text_predictions['File_Name'])
audio_filenames = set(audio_predictions['File_Name'])

# Find mismatches
only_in_text = text_filenames - audio_filenames
only_in_audio = audio_filenames - text_filenames

# Print differences
print(f"Filenames only in text predictions: {only_in_text}")
print(f"Filenames only in audio predictions: {only_in_audio}")

# Keep only common filenames
common_filenames = text_filenames & audio_filenames

# Filter both DataFrames to keep only common filenames
text_predictions = text_predictions[text_predictions['File_Name'].isin(common_filenames)]
audio_predictions = audio_predictions[audio_predictions['File_Name'].isin(common_filenames)]

# Sort and reset index to align both files properly
text_predictions = text_predictions.sort_values(by='File_Name').reset_index(drop=True)
audio_predictions = audio_predictions.sort_values(by='File_Name').reset_index(drop=True)

# Majority fusion without weighting
fused_predictions = []
for _, (text_row, audio_row) in enumerate(zip(text_predictions.itertuples(), audio_predictions.itertuples())):
    File_Name = text_row.File_Name
    text_label = text_row.fused_label
    audio_label = audio_row.fused_label

    # Equal voting
    vote_counter = Counter([text_label, audio_label])

    # Select the label with the highest count
    fused_label = vote_counter.most_common(1)[0][0]
    fused_predictions.append({"File_Name": File_Name, "fused_label": fused_label})

# Save to TSV file
fused_predictions_df = pd.DataFrame(fused_predictions)
output_fused_file = "/content/SSNCSE_MAlayalam_Run2.tsv"
fused_predictions_df.to_csv(output_fused_file, sep="\t", index=False)

print(f"Final fused predictions saved to {output_fused_file}.")
# Out:
# Filenames only in text predictions: set()
# Filenames only in audio predictions: set()
# Final fused predictions saved to /content/SSNCSE_Malayalam_Run2.tsv.

# %%
from sklearn.metrics import classification_report
import pandas as pd
from sklearn.preprocessing import LabelEncoder

# Load the true labels from the Excel file (Sheet1)
true_labels_file = "/content/ML-AT-test.xlsx - Sheet1.tsv"
true_labels_data = pd.read_csv(true_labels_file, sep='\t')

# Load the predicted labels from the TSV file
predicted_labels_file = "/content/SSNCSE_MAlayalam_Run2.tsv"
predicted_data = pd.read_csv(predicted_labels_file, sep='\t')

# Ensure both datasets have the same 'File Name' column for alignment
# Remove leading/trailing spaces from all column names
true_labels_data.columns = true_labels_data.columns.str.strip()

# Now merge the datasets using the cleaned column names
merged_data = pd.merge(true_labels_data[['File_Name', 'Class Label']],
                       predicted_data[['File_Name', 'fused_label']],
                       on='File_Name')

# Extract true labels and predicted labels
y_true = merged_data['Class Label']
y_pred = merged_data['fused_label']

# Continue with the rest of your code...
# Encode the true and predicted labels (if needed)
label_encoder = LabelEncoder()
y_true_encoded = label_encoder.fit_transform(y_true)
y_pred_encoded = label_encoder.transform(y_pred)

# Generate the classification report
print(classification_report(y_true_encoded, y_pred_encoded, target_names=label_encoder.classes_))
# Out:
#               precision    recall  f1-score   support
#
#            C       0.32      1.00      0.49        10
#            G       0.67      0.20      0.31        10
#            N       0.73      0.80      0.76        10
#            P       0.00      0.00      0.00        10
#            R       0.25      0.10      0.14        10
#
#     accuracy                           0.42        50
#    macro avg       0.39      0.42      0.34        50
# weighted avg       0.39      0.42      0.34        50
